# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Visualización con Matplotlib: Algunos elementos de apoyo

# %% [markdown]
# En esta sesión vamos a trabajar con las leyendas, los textos añadidos y en cómo marcar con flechas y señalar algunas zonas importantes de nuestras figuras y gráficas. Empecemos importando lo necesario:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Manipulando leyendas

# %% [markdown]
# Recordemos como se creaba una leyenda, básicamente añadíamos una etiqueta a las gráficas y luego llamábamos a la función `plt.legend`:

# %%
x = np.linspace(0,10,100)
fig,ax = plt.subplots()
ax.plot(x, np.sin(x), "-b", label = "seno")
ax.plot(x, np.cos(x), "--r", label = "coseno")
ax.axis("equal")
ax.legend();

# %% [markdown]
# Y vamos a ver como:
# * Ponerle título, con el argumento `title`
# * Cambiar la posición de la leyenda, con el argumento `loc`
# * Quitar el marco y ponerlo con el argumento `frameon`
# * Indicar el núméro de columnas de la leyenda con `ncol`

# %%
# Titulo
ax.legend(loc = "upper right", title = "Bootcamp")
fig

# %%
# Centro arriba, abajo izquierda, best
ax.legend(loc = "center right", title = "Bootcamp")
fig

# %%
# Sin marco
ax.legend(loc = "upper right", title = "Bootcamp", frameon = False)
fig

# %%
# numero de columna
ax.legend(loc = "upper right", title = "Bootcamp", ncol=2)
fig

# %% [markdown]
# #### Truquitos (I): Leyendas para el tamaño de los puntos [y pequeño repaso]

# %% [markdown]
# A veces, los valores predeterminados de la leyenda no son suficientes para la visualización dada.
# Por ejemplo, tal vez estés utilizando el tamaño de los puntos para marcar ciertas características de los datos, y quieras crear una leyenda que refleje esto.  Además también aprenderemos algo sobre la barra de colores o color bar.
#
# Aquí tienes un ejemplo donde usaremos el tamaño de los puntos para indicar las poblaciones de las ciudades de California.
# Nos gustaría una leyenda que especifique la escala de los tamaños de los puntos, y lo lograremos trazando algunos datos etiquetados sin entradas:

# %%
# Leer dataframe 
cities = pd.read_csv("./data/california_cities.csv")
cities
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# 1           922.0             20330             7.822            7.793
# 2            33.0             75467            22.960           10.611
# 3            43.0             18969             5.465            1.788
# 4           492.0             83089             7.632            7.631
# ..            ...               ...               ...              ...
# 477          98.0              2933             1.531            1.531
# 478        2582.0              7765            10.053            9.980
# 479          59.0             64925            14.656           14.578
# 480        2618.0             51367            27.893           27.888
# 481        3369.0             20700            40.015           40.015
#
#      area_water_sq_mi  area_total_km2  area_land_km2  area_water_km2  \
# 0               0.018         145.107        145.062           0.046
# 1               0.029          20.260         20.184           0.076
# 2              12.349          59.465         27.482          31.983
# 3               3.677          14.155          4.632           9.524
# 4               0.001          19.766         19.763           0.003
# ..                ...             ...            ...             ...
# 477             0.000           3.966          3.966           0.000
# 478             0.073          26.036         25.847           0.188
# 479             0.078          37.959         37.758           0.201
# 480             0.005          72.244         72.231           0.013
# 481             0.000         103.639        103.639           0.000
#
#      area_water_percent
# 0                  0.03
# 1                  0.37
# 2                 53.79
# 3                 67.28
# 4                  0.01
# ..                  ...
# 477                0.00
# 478                0.72
# 479                0.53
# 480                0.02
# 481                0.00
#
# [482 rows x 14 columns]

# %% [markdown]
# Practiquemos además un poco con todo lo aprendido en las sesiones anteriores:

# %%
# Dispersion, barra de colores
lat, lon = cities ["latd"], cities["longd"]
population, area = cities["population_total"], cities["area_total_km2"]

plt.figure(figsize = (20,10))
plt.scatter(lon, lat, c = np.log10(population), cmap = "viridis",
           s = area, linewidth = 0, alpha = 0.5)

plt.xlabel("Longitudes")
plt.ylabel("Latitudes")
plt.colorbar(label = "log$_{10}$(population)")
plt.clim(3,7)

# %%
# Fake legend
for area in  [100,300,500]:
    plt.scatter([],[], c = "k", alpha = 0.3, s = area, label = str(area) + "Km$^2$")
plt.legend(frameon = False, title = "Area Ciudad");

# %%
# Todo junto
# Dispersion, barra de colores
lat, lon = cities ["latd"], cities["longd"]
population, area = cities["population_total"], cities["area_total_km2"]

plt.figure(figsize = (20,10))
plt.scatter(lon, lat, c = np.log10(population), cmap = "viridis",
           s = area, linewidth = 0, alpha = 0.5)

plt.xlabel("Longitudes")
plt.ylabel("Latitudes")
plt.colorbar(label = "log$_{10}$(population)")
plt.clim(3,7)

# Fake legend
for area in  [100,300,500]:
    plt.scatter([],[], c = "k", alpha = 0.3, s = area, label = str(area) + "Km$^2$")
plt.legend(frameon = False, title = "Area Ciudad");

plt.title('California Cities: Area and Population');

# %% [markdown]
# ### Textos, anotaciones y flechas

# %% [markdown]
# #### Texto
#
# Ya lo vimos, de pasada, al hablar de subplots y marcar estos. Es sencillo:

# %%
# Generamos una gráfica simple
x = np.linspace(0, 10, 100)
y = np.sin(x)
min_x_value = pd.Series(y, index= x).idxmin()
min_y_value = pd.Series(y, index= x).min()
plt.figure(figsize=(8, 4))
plt.plot(x, y)
plt.title(r"Gráfica del $sin(x)$ con Anotaciones")
plt.xlabel("x")
plt.ylabel("sin(x)")
# Out:
# Text(0, 0.5, 'sin(x)')

# %%
# Añadir texto en la gráfica
x = np.linspace(0, 10, 100)
y = np.sin(x)
min_x_value = pd.Series(y, index= x).idxmin()
min_y_value = pd.Series(y, index= x).min()
plt.figure(figsize=(8, 4))
plt.plot(x, y)
plt.title(r"Gráfica del $sin(x)$ con Anotaciones")
plt.xlabel("x")
plt.ylabel("sin(x)")


font_dict = {
    "size": 16,
    "family": "Brush Script MT",
    "color": "darkblue"
}
plt.text(min_x_value, min_y_value, "Valor minimo", foundict = font_dict,)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 18
#      10 plt.ylabel("sin(x)")
#      13 font_dict = {
#      14     "size": 16,
#      15     "family": "Brush Script MT",
#      16     "color": "darkblue"
#      17 }
# ---> 18 plt.text(min_x_value, min_y_value, "Valor minimo", foundict = font_dict,)
#
# File c:\Users\lupep\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\pyplot.py:4207, in text(x, y, s, fontdict, **kwargs)
#    4203 @_copy_docstring_and_deprecators(Axes.text)
#    4204 def text(
#    4205     x: float, y: float, s: str, fontdict: dict[str, Any] | None = None, **kwargs
#    4206 ) -> Text:
# -> 4207     return gca().text(x, y, s, fontdict=fontdict, **kwargs)
#
# File c:\Users\lupep\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\axes\_axes.py:710, in Axes.text(self, x, y, s, fontdict, **kwargs)
#     639 """
#     640 Add text to the Axes.
#     641
#    (...)    700     >>> text(x, y, s, bbox=dict(facecolor='red', alpha=0.5))
#     701 """
#     702 effective_kwargs = {
#     703     'verticalalignment': 'baseline',
#     704     'horizontalalignment': 'left',
#    (...)    708     **kwargs,
#     709 }
# --> 710 t = mtext.Text(x, y, text=s, **effective_kwargs)
#     711 if t.get_clip_path() is None:
#     712     t.set_clip_path(self.patch)
#
# File c:\Users\lupep\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\text.py:155, in Text.__init__(self, x, y, text, color, verticalalignment, horizontalalignment, multialignment, fontproperties, rotation, linespacing, rotation_mode, usetex, wrap, transform_rotates_text, parse_math, antialiased, **kwargs)
#     138 self._text = ''
#     139 self._reset_visual_defaults(
#     140     text=text,
#     141     color=color,
#    (...)    153     antialiased=antialiased
#     154 )
# --> 155 self.update(kwargs)
#
# File c:\Users\lupep\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File c:\Users\lupep\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\artist.py:1223, in Artist.update(self, props)
#    1215 def update(self, props):
#    1216     """
#    1217     Update this artist's properties from the dict *props*.
#    1218
#    (...)   1221     props : dict
#    1222     """
# -> 1223     return self._update_props(
#    1224         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File c:\Users\lupep\AppData\Local\Programs\Python\Python313\Lib\site-packages\matplotlib\artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: 'Text' object has no property 'foundict'

# %% [markdown]
# [Aquí](https://jonathansoma.com/lede/data-studio/matplotlib/list-all-fonts-available-in-matplotlib-plus-samples/) puedes encontrar una lista de fuentes disponibles en Matplotlib (aunque puede que no te fucionen todas).

# %% [markdown]
# Y ahora veamos otra forma de añadir texto con flechas de diversa forma para poder marcar y anotar nuestras gráficas.

# %% [markdown]
# #### Flechas y anotaciones

# %% [markdown]
# Veamos como añadir una anotación no necesariamente donde se produce y marcar ese punto con una flecha:

# %%
# Repetir la gráfica simple
x = np.linspace(0, 10, 100)
y = np.sin(x)
min_x_value = pd.Series(y, index= x).idxmin()
min_y_value = pd.Series(y, index= x).min()
plt.figure(figsize=(8, 4))
plt.plot(x, y)
plt.title(r"Gráfica del $sin(x)$ con Anotaciones")
plt.xlabel("x")
plt.ylabel("sin(x)")

props_flecha = {
    "arrowstyle": "<->",
    "connectionstyle": "angle3"
}
plt.annotate("Valor minimo", xy = (min_x_value, min_y_value), xytext = (min_x_value, 0.5),
    arrowprops = props_flecha)
# Out:
# Text(4.747474747474747, 0.5, 'Valor minimo')

# %%
# Añadir antoación con flecha indicativa
props_flecha = {
    "arrowstyle": "<->",
    "connectionstyle": "angle3"
}
plt.annotate("Valor minimo", xy = (min_x_value, min_y_value), xytext = (min_x_value, 0.5),
    arrowprops = props_flecha)
